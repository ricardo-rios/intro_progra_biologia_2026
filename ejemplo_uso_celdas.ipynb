# %% [markdown]
# # Seccion 1
#
# ## Mi pimera linea de codigo
#
# A continuación escribiremos una linea de código.

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# # Seccion 2
#
# ## Otra linea de código

# %%
print("Hola de nuevo")
# Out:
# Hola de nuevo
