# %% [markdown]
# # Entrada y Salida
#
#
# En esta lección, además de describir más detalladamente del uso de
# print para mostrar mensajes al usuario, aprenderemos a utilizar las
# funciones input y raw_input para pedir información.

# %% [markdown]
# ## Entrada estándar
#
# La forma más sencilla de obtener información por parte del usuario
# es mediante la función input. Esta función toma como parámetro una cadena a usar como prompt (es decir, como texto a mostrar al
# usuario pidiendo la entrada) y devuelve una cadena con los caracteres
# introducidos por el usuario hasta que pulsó la tecla Enter. Veamos un
# pequeño ejemplo:

# %%
nombre = input("Como te llamas? ")
print("Encantado " + nombre)

# %% [markdown]
# Si necesitáramos un entero como entrada en lugar de una cadena, por
# ejemplo, podríamos utilizar la función int para convertir la cadena a
# entero, aunque sería conveniente tener en cuenta que puede lanzarse
# una excepción si lo que introduce el usuario no es un número. Posteriormente en la unidad IV discutiremos como hacer más robusto el código para que tenga en cuenta valores inesperados en la entrada de usuario usando excepciones con el bloque try y except.

# %%
edad = input("Digite su edad ")
dias = int(edad) * 365
print("Has vivido " + str(dias) + " dias")
# Out:
# Digite su edad 10
# Has vivido 3650 dias

# %% [markdown]
# ## Salida estándar
#
# La forma más sencilla de mostrar algo en la salida estándar es mediante el uso de la sentencia print, como hemos visto multitud de veces en ejemplos anteriores. En su forma más básica a la palabra clave print le
# sigue una cadena, que se mostrará en la salida estándar al ejecutarse el
# estamento.

# %%
print("Hola Mundo!")
# Out:
# Hola Mundo!

# %% [markdown]
# ## Ejercicios
#
# ### Ejercicio 1
#
# 1. Solicite al usuario su nombre usando la función `input`.
# 2. Solicite su ciudad de origen.
# 3. Muestre un mensaje en pantalla utilizando `print` con el siguiente formato:
#
# Hola, mi nombre es \<nombre\> y soy de \<ciudad\>.

# %% [markdown]
# ### Ejercicio 2: Cálculo de edad en horas
#
# Escribe un programa que:
#
# 1. Pida al usuario su edad en años.
# 2. Convierta la entrada a número entero usando `int`.
# 3. Calcule aproximadamente cuántas horas ha vivido (suponiendo 365 días por año).
# 4. Muestre el resultado en pantalla.
#
# **Fórmula:**
# $ horas = edad \times 365 \times 24 $
#
# **Ejemplo de salida esperada:**
#
#
# Has vivido aproximadamente 175200 horas.

# %% [markdown]
# ### Ejercicio 3: Operaciones con números ingresados por el usuario
#
# Escribe un programa que:
#
# 1. Solicite al usuario dos números enteros.
# 2. Convierta ambas entradas a tipo `int`.
# 3. Muestre en pantalla:
#    - La suma
#    - La resta
#    - La multiplicación
#
# El formato de salida debe ser claro, por ejemplo:
#
# La suma es: 15
#
# La resta es: 3
#
# La multiplicación es: 54
